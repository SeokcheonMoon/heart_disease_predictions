# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용 - 리눅스 사용할때
import scipy
import scipy.stats as stats

import os
import re
import time
import datetime as dt # 사용시 datetime.dt 로 사용 # 현재 시간 사용
from datetime import datetime # 사용시 함수로 바로 사용 #-> 시간 비교

# %%
### 한글 폰트 설치 - 윈도우 사용할 때
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

path = 'c:/Windows/Fonts/malgun.ttf'  # 또는 나눔고딕: 'c:/Windows/Fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
# 경고창 무시
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 데이터 불러오기

# %%
df_heart_stable = pd.read_csv("../../dataset/df_heart_stable.csv", index_col = 0)
df_heart_stable.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke PhysicalHealth  \
# 0           No    저체중     Yes              No     No             나쁨
# 1           No  정상 체중      No              No    Yes             나쁨
# 2           No    과체중     Yes              No     No             좋음
# 3           No  정상 체중      No              No     No             나쁨
# 4           No  정상 체중      No              No     No             좋음
#
#   MentalHealth DiffWalking     Sex AgeCategory   Race Diabetic  \
# 0           좋음          No  Female         노년기  White      Yes
# 1           나쁨          No  Female         노년기  White       No
# 2           좋음          No    Male         노년기  White      Yes
# 3           나쁨          No  Female         노년기  White       No
# 4           나쁨         Yes  Female         청년기  White       No
#
#   PhysicalActivity  GenHealth SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good       불면증    Yes            No        Yes
# 1              Yes  Very good        정상     No            No         No
# 2              Yes       Fair        정상    Yes            No         No
# 3               No       Good        정상     No            No        Yes
# 4              Yes  Very good        정상     No            No         No
