# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용 - 리눅스 사용할때
import scipy
import scipy.stats as stats

import os
import re
import time
import datetime as dt # 사용시 datetime.dt 로 사용 # 현재 시간 사용
from datetime import datetime # 사용시 함수로 바로 사용 #-> 시간 비교

# %%
### 한글 폰트 설치 - 윈도우 사용할 때
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

path = 'c:/Windows/Fonts/malgun.ttf'  # 또는 나눔고딕: 'c:/Windows/Fonts/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
# 경고창 무시
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 데이터 전처리

# %%
df_heart = pd.read_csv("../../dataset/heart_2020_cleaned.csv")
df_heart.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
# BMI 사분위수를 이용한 이상치 제거
Q1 = 24.030000
Q3 = 31.420000
IQR = Q3-Q1
print(f"(1) Q1-1.5*IQR 값 : {Q1-1.5*IQR}")
print(f"(2) Q3+1.5*IQR 값 : {Q3+1.5*IQR}")

condition_bmi = f"{Q1-1.5*IQR} <= BMI <= {Q3+1.5*IQR}"
# Out:
# (1) Q1-1.5*IQR 값 : 12.945
# (2) Q3+1.5*IQR 값 : 42.505

# %%
# BMI 기준 정의
def classify_bmi(bmi):
    if bmi < 18.5:
        return '저체중'
    elif 18.5 <= bmi <= 24.9:
        return '정상 체중'
    elif 25 <= bmi <= 29.9:
        return '과체중'
    elif 30 <= bmi <= 34.9:
        return '경도 비만'
    elif 35 <= bmi <= 39.9:
        return '중도 비만'
    else:
        return '고도 비만'

# Sleeping 기준 정의
def classify_sleep(hours):
    if hours < 6:
        return '불면증'
    elif 6 <= hours <= 9:
        return '정상'
    else:
        return '과다 수면'

# 신체 건강 정도 범주화
def classify_physical(value):
    if value < 3.24:
        return '나쁨'
    else:
        return '좋음'

# 정신 건강 정도 범주화
def classify_mental(value):
    if value < 3.80:
        return '나쁨'
    else:
        return '좋음'

# 나이 범주화
def classify_age_category(age_range):
    if age_range in ['18-24']:
        return '청소년기'
    elif age_range in ['25-29', '30-34', '35-39', '40-44', '45-49']:
        return '청년기'
    elif age_range in ['50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80 or older']:
        return '노년기'

# bmi 이상치 제거(df_heart_stable 생성)
df_heart_stable = df_heart.query(condition_bmi)

df_heart_stable['BMI'] = df_heart_stable['BMI'].apply(classify_bmi)
df_heart_stable['SleepTime'] = df_heart_stable['SleepTime'].apply(classify_sleep)
df_heart_stable['PhysicalHealth'] = df_heart_stable['PhysicalHealth'].apply(classify_physical)
df_heart_stable['MentalHealth'] = df_heart_stable['MentalHealth'].apply(classify_mental)
df_heart_stable['AgeCategory'] = df_heart_stable['AgeCategory'].apply(classify_age_category)

# %%
df_heart_stable.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke PhysicalHealth  \
# 0           No    저체중     Yes              No     No             나쁨
# 1           No  정상 체중      No              No    Yes             나쁨
# 2           No    과체중     Yes              No     No             좋음
# 3           No  정상 체중      No              No     No             나쁨
# 4           No  정상 체중      No              No     No             좋음
# 5          Yes    과체중     Yes              No     No             좋음
# 6           No  정상 체중      No              No     No             좋음
# 7           No  경도 비만     Yes              No     No             좋음
# 8           No    과체중      No              No     No             나쁨
# 9           No  고도 비만      No              No     No             나쁨
#
#   MentalHealth DiffWalking     Sex AgeCategory   Race  \
# 0           좋음          No  Female         노년기  White
# 1           나쁨          No  Female         노년기  White
# ...

# %% [markdown]
# ## 가설 검증

# %%
# BMI

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['BMI'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. BMI는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. BMI는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 881.6452980968525
# p-value: 2.4968509456926454e-188
# 귀무가설을 기각합니다. BMI는 심장 질환과 상관관계가 있습니다.

# %%
# Smoking

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Smoking'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 흡연 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 흡연 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 3636.1036735815296
# p-value: 0.0
# 귀무가설을 기각합니다. 흡연 여부는 심장 질환과 상관관계가 있습니다.

# %%
# AlcoholDrinking

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['AlcoholDrinking'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 음주 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 음주 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 330.66879877407956
# p-value: 6.872623181433505e-74
# 귀무가설을 기각합니다. 음주 여부는 심장 질환과 상관관계가 있습니다.

# %%
# Stroke

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Stroke'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 뇌졸증 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 뇌졸증 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 11981.802940363
# p-value: 0.0
# 귀무가설을 기각합니다. 뇌졸증 여부는 심장 질환과 상관관계가 있습니다.

# %%
# PhysicalHealth

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['PhysicalHealth'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 물리적 건강은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 물리적 건강은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 6976.677744495204
# p-value: 0.0
# 귀무가설을 기각합니다. 물리적 건강은 심장 질환과 상관관계가 있습니다.

# %%
# MentalHealth

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['MentalHealth'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 정신적 건강은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 정신적 건강은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 1.9717128801140782
# p-value: 0.16026616673045257
# 귀무가설을 기각하지 않습니다. 정신적 건강은 심장 질환과 상관관계가 없습니다.

# %%
# DiffWalking

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['DiffWalking'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 보행 시 어려움 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 보행 시 어려움 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 12387.19010106483
# p-value: 0.0
# 귀무가설을 기각합니다. 보행 시 어려움 여부는 심장 질환과 상관관계가 있습니다.

# %%
# Sex

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Sex'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 성별은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 성별은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 1538.8616212804861
# p-value: 0.0
# 귀무가설을 기각합니다. 성별은 심장 질환과 상관관계가 있습니다.

# %%
# AgeCategory

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['AgeCategory'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 연령은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 연령은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 11309.21444312902
# p-value: 0.0
# 귀무가설을 기각합니다. 연령은 심장 질환과 상관관계가 있습니다.

# %%
# Race

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Race'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 인종은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 인종은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 824.787076892126
# p-value: 5.0196352327939694e-176
# 귀무가설을 기각합니다. 인종은 심장 질환과 상관관계가 있습니다.

# %%
# Diabetic

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Diabetic'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 당뇨 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 당뇨 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 10400.43425298574
# p-value: 0.0
# 귀무가설을 기각합니다. 당뇨 여부는 심장 질환과 상관관계가 있습니다.

# %%
# PhysicalActivity

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['PhysicalActivity'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 신체 활동 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 신체 활동 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 2988.0930549442874
# p-value: 0.0
# 귀무가설을 기각합니다. 신체 활동 여부는 심장 질환과 상관관계가 있습니다.

# %%
# GenHealth

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['GenHealth'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 주관적 건강 상태는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 주관적 건강 상태는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 20890.771978196302
# p-value: 0.0
# 귀무가설을 기각합니다. 주관적 건강 상태는 심장 질환과 상관관계가 있습니다.

# %%
# SleepTime

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['SleepTime'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 수면 시간은 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 수면 시간은 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 1465.3199427452098
# p-value: 0.0
# 귀무가설을 기각합니다. 수면 시간은 심장 질환과 상관관계가 있습니다.

# %%
# Asthma

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['Asthma'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 천식 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 천식 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 473.4014474490935
# p-value: 5.829005942586741e-105
# 귀무가설을 기각합니다. 천식 여부는 심장 질환과 상관관계가 있습니다.

# %%
# KidneyDisease

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['KidneyDisease'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 신장 질환 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 신장 질환 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 6229.208589427029
# p-value: 0.0
# 귀무가설을 기각합니다. 신장 질환 여부는 심장 질환과 상관관계가 있습니다.

# %%
# SkinCancer

from scipy.stats import chi2_contingency

# 교차 테이블 생성
contingency_table = pd.crosstab(df_heart_stable['SkinCancer'], df_heart_stable['HeartDisease'])

# 카이제곱 검정 수행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print("카이제곱 통계량:", chi2)
print("p-value:", p)
# print("자유도:", dof)
# print("기대 빈도:\n", expected)

# p-value 해석
alpha = 0.05
if p < alpha:
    print("귀무가설을 기각합니다. 피부암 여부는 심장 질환과 상관관계가 있습니다.")
else:
    print("귀무가설을 기각하지 않습니다. 피부암 여부는 심장 질환과 상관관계가 없습니다.")
# Out:
# 카이제곱 통계량: 2766.615617626174
# p-value: 0.0
# 귀무가설을 기각합니다. 피부암 여부는 심장 질환과 상관관계가 있습니다.

# %% [markdown]
# ## 카이제곱 관계성 검증 결과
#
# - 정신적 질환을 제외한 모든 컬럼이 심장 질환과 관련성을 가지고 있음.
